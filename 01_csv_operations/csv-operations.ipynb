# %% [markdown]
# ## 1. Importing pandas (to deal with dataframes)

# %%
import pandas as pd

# %% [markdown]
# ## 2. Opening a csv file located on PC

# %%
# set the path according to the file location
df = pd.read_csv('../datasets/iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## 3. Opening a csv file from a URL

# %%
import requests
from io import StringIO

url = "https://gist.githubusercontent.com/kevin336/acbb2271e66c10a5b73aacf82ca82784/raw/e38afe62e088394d61ed30884dd50a6826eee0a8/employees.csv"
# mention headers (as the request may be prohibited sometimes on some links as those requests
# will be considered as bots etc)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0"
}

req = requests.get(url, headers=headers)

#convert the text of the request and store it in a variable
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %% [markdown]
# ## 4. Sep Parameter

# %%
# a tab separated valued file
pd.read_csv('../datasets/small_iris.tsv',sep='\t')
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# ...

# %%
# loading with our own columns name and skipping the row of the cols name specified in dataset
pd.read_csv('../datasets/small_iris.tsv',sep='\t',names=['sp len','sep wid','pet len','pet wid','species'],skiprows=[0])
# Out:
#     sp len  sep wid  pet len  pet wid species
# 0      5.1      3.5      1.4      0.2  setosa
# 1      4.9      3.0      1.4      0.2  setosa
# 2      4.7      3.2      1.3      0.2  setosa
# 3      4.6      3.1      1.5      0.2  setosa
# 4      5.0      3.6      1.4      0.2  setosa
# 5      5.4      3.9      1.7      0.4  setosa
# 6      4.6      3.4      1.4      0.3  setosa
# 7      5.0      3.4      1.5      0.2  setosa
# 8      4.4      2.9      1.4      0.2  setosa
# 9      4.9      3.1      1.5      0.1  setosa
# 10     5.4      3.7      1.5      0.2  setosa
# 11     4.8      3.4      1.6      0.2  setosa
# 12     4.8      3.0      1.4      0.1  setosa
# 13     4.3      3.0      1.1      0.1  setosa
# 14     5.8      4.0      1.2      0.2  setosa

# %% [markdown]
# # 5. Index_col parameter

# %%
# make PassengerId as my index instead of auto generated(0,1,2..)
pd.read_csv('../datasets/titanic.csv',index_col='PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ## 6. Header parameter

# %%
# here basically our cols name are actually at row one, so in next cell, we'll keep header=1
# without header
pd.read_csv('../datasets/test.csv')
# Out:
#                 0            5           345          453    453.0
# 0    sepal_length  sepal_width  petal_length  petal_width  species
# 1             5.1          3.5           1.4          0.2      1.0
# 2             4.9            3           1.4          0.2      1.0
# 3             4.7          3.2           1.3          0.2      1.0
# 4             4.6          3.1           1.5          0.2      1.0
# ..            ...          ...           ...          ...      ...
# 146           6.7            3           5.2          2.3      3.0
# 147           6.3          2.5             5          1.9      3.0
# 148           6.5            3           5.2            2      3.0
# 149           6.2          3.4           5.4          2.3      3.0
# 150           5.9            3           5.1          1.8      3.0
#
# [151 rows x 5 columns]

# %%
# with header
pd.read_csv('../datasets/test.csv',header=1)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2      1.0
# 1             4.9          3.0           1.4          0.2      1.0
# 2             4.7          3.2           1.3          0.2      1.0
# 3             4.6          3.1           1.5          0.2      1.0
# 4             5.0          3.6           1.4          0.2      1.0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3      3.0
# 146           6.3          2.5           5.0          1.9      3.0
# 147           6.5          3.0           5.2          2.0      3.0
# 148           6.2          3.4           5.4          2.3      3.0
# 149           5.9          3.0           5.1          1.8      3.0
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 7. use_cols parameter

# %%
#to select specific cols from a dataset
pd.read_csv('../datasets/titanic.csv',usecols=['Survived','Pclass','Sex','Age','SibSp','Parch','Fare','Embarked'])
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# ## 8. Squeeze Function

# %%
# to convert one columns to a Pandas Series instead of pandas data frame
pd.read_csv('../datasets/titanic.csv',usecols=['PassengerId']).squeeze()
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %% [markdown]
# ## 9. Skiprows/nrows Parameter

# %%
'''the dataset has more than 900 rows, but it will select only 100(nrows), 
and will skip the first row from the original dataset as skiprows=1'''
pd.read_csv('../datasets/titanic.csv',nrows=100, skiprows=[1])
# Out:
#     PassengerId  Survived  Pclass  \
# 0             2         1       1
# 1             3         1       3
# 2             4         1       1
# 3             5         0       3
# 4             6         0       3
# ..          ...       ...     ...
# 95           97         0       1
# 96           98         1       1
# 97           99         1       2
# 98          100         0       2
# 99          101         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1                              Heikkinen, Miss. Laina  female  26.0      0
# 2        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 3                            Allen, Mr. William Henry    male  35.0      0
# 4                                    Moran, Mr. James    male   NaN      0
# ..                                                ...     ...   ...    ...
# ...

# %% [markdown]
# ## 10. Encoding parameter

# %%
# this csv file doesnt have utf-8 encoding, so we will mention the specific encoding of that
pd.read_csv('../datasets/zomato.csv',encoding='latin-1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# ## 11. dtypes parameter

# %%
# it shows the species/label in float, which could be represented as integer
pd.read_csv('../datasets/test.csv', header=1)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2      1.0
# 1             4.9          3.0           1.4          0.2      1.0
# 2             4.7          3.2           1.3          0.2      1.0
# 3             4.6          3.1           1.5          0.2      1.0
# 4             5.0          3.6           1.4          0.2      1.0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3      3.0
# 146           6.3          2.5           5.0          1.9      3.0
# 147           6.5          3.0           5.2          2.0      3.0
# 148           6.2          3.4           5.4          2.3      3.0
# 149           5.9          3.0           5.1          1.8      3.0
#
# [150 rows x 5 columns]

# %%
# so here we are getting our target/species col as integer instead of float.
pd.read_csv('../datasets/test.csv', header=1 ,dtype={'species':int})
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        3
# 146           6.3          2.5           5.0          1.9        3
# 147           6.5          3.0           5.2          2.0        3
# 148           6.2          3.4           5.4          2.3        3
# 149           5.9          3.0           5.1          1.8        3
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 12. Handling Dates

# %%
pd.read_csv('../datasets/Electric_Production.csv').info()
print("***************************************************************************")
pd.read_csv('../datasets/Electric_Production.csv',parse_dates=['DATE']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        397 non-null    object
#  1   IPG2211A2N  397 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 6.3+ KB
# ***************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        397 non-null    datetime64[ns]
#  1   IPG2211A2N  397 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 6.3 KB

# %% [markdown]
# ## 13. Convertors

# %%
def rename(val):
    if val == "male":
        return "M"
    elif val == "female":
        return "F"
    else:
        return val

# %%
pd.read_csv('../datasets/titanic.csv',converters={'Sex':rename})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   M  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1
# 2                               Heikkinen, Miss. Laina   F  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0      1
# 4                             Allen, Mr. William Henry   M  35.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %% [markdown]
# ## 14. na_values parameter

# %%
# na_values tells pandas which values should be treated as missing (NaN) when reading the CSV

pd.read_csv('../datasets/titanic.csv',na_values={
        'Cabin': [''],    # empty strings in Cabin → NaN
        'Age': ['']       # empty strings in Age → NaN
    })
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 15. Loading bigger datasets in chunks

# %%
dframes = pd.read_csv('../datasets/titanic.csv',chunksize=200)

# %%
for chunks in dframes:
    print(chunks.shape)
# Out:
# (200, 12)
# (200, 12)
# (200, 12)
# (200, 12)
# (91, 12)
