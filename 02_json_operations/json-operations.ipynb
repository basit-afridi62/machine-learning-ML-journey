# %%
import pandas as pd

# %% [markdown]
# ## 1. Uploading json file from local storage and converting into a dataframe

# %%
pd.read_json('../datasets/titanic.json')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  \
# 0                            "Braund, Mr. Owen Harris"
# 1    "Cumings, Mrs. John Bradley (Florence Briggs T...
# 2                             "Heikkinen, Miss. Laina"
# 3       "Futrelle, Mrs. Jacques Heath (Lily May Peel)"
# 4                           "Allen, Mr. William Henry"
# ..                                                 ...
# 886                            "Montvila, Rev. Juozas"
# 887                     "Graham, Miss. Margaret Edith"
# ...

# %% [markdown]
# ## 2. Getting json file from an URL and converting into a dataframe

# %%
pd.read_json('https://raw.githubusercontent.com/ybifoundation/Dataset/main/Titanic.json')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...
